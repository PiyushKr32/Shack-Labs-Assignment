# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

from warnings import filterwarnings
filterwarnings("ignore")

# %%
amz_df=pd.read_csv('amz_com-ecommerce_sample.csv',encoding='unicode_escape')
flp_df=pd.read_csv('flipkart_com-ecommerce_sample.csv',encoding='unicode_escape')

# %%
amz_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
amz_df.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
amz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
# Missing values in amazon dataset

amz_df.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                  0
# discounted_price              0
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
flp_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
flp_df.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
flp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
flp_df.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %%
# Missing values in flipkart dataset

flp_df.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                 78
# discounted_price             78
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
# Retail_price and discounted_price columns are having null values in flipkart dataset.
# These values are important for us in comparisions
# So we will find the rows index and drop it in both datasets.

nullindex = pd.isnull(Flp_df['retail_price'])
flp_df[nullindex]
# Out:
#                                 uniq_id            crawl_timestamp  \
# 12     c29af37837afcaf44b779eca7c19295f  2016-03-25 22:59:23 +0000
# 21     ea98a65ad1e1b8688eddf89fbc7b3e27  2016-03-25 22:59:23 +0000
# 76     64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 812    39ed975091fd6d1d3ef3a7d33b8c4360  2016-01-06 18:20:45 +0000
# 1318   115ecd52f86ebf7a5509d0959a2caaa0  2016-03-25 15:39:25 +0000
# ...                                 ...                        ...
# 16762  43fbafdae704714c6543690161d3adb1  2015-12-20 08:26:17 +0000
# 17634  9d37d5a4ce327fb84cec4f56a2f0ac38  2016-05-22 10:35:27 +0000
# 19543  21c408cc5df0f78b3831ab1686c8dc68  2015-12-01 10:15:43 +0000
# 19599  c8db5fb95df382f7f5719609d0f02f80  2015-12-01 10:15:43 +0000
# 19622  950b6714a17d33211141fc4134ef1c5d  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 12     http://www.flipkart.com/sicons-all-purpose-tea...
# ...

# %%
flp_df[nullindex].index
# Out:
# Int64Index([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
#              3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
#              7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
#              8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
#             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
#             11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
#             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
#             12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
#             16487, 16762, 17634, 19543, 19599, 19622],
#            dtype='int64')

# %%
# Dropping null values present in Flp data and also in Amz data

# %%
amz_df.drop([12, 21, 76, 812, 1318, 1734, 2977, 3233, 3404, 3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190, 8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393, 11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541, 12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
             16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
flp_df.drop([12, 21, 76, 812, 1318, 1734, 2977, 3233, 3404, 3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190, 8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393, 11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541, 12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
             16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
# Now Retail and discounted price columns are in equal quantity now

flp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19922 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  19922 non-null  object
#  1   crawl_timestamp          19922 non-null  object
#  2   product_url              19922 non-null  object
#  3   product_name             19922 non-null  object
#  4   product_category_tree    19922 non-null  object
#  5   pid                      19922 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19919 non-null  object
#  9   is_FK_Advantage_product  19922 non-null  bool
#  10  description              19920 non-null  object
#  11  product_rating           19922 non-null  object
#  12  overall_rating           19922 non-null  object
#  13  brand                    14071 non-null  object
# ...

# %%
amz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19922 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  19922 non-null  object
#  1   crawl_timestamp          19922 non-null  object
#  2   product_url              19922 non-null  object
#  3   product_name             19922 non-null  object
#  4   product_category_tree    19922 non-null  object
#  5   pid                      19922 non-null  object
#  6   retail_price             19922 non-null  int64
#  7   discounted_price         19922 non-null  int64
#  8   image                    19919 non-null  object
#  9   is_FK_Advantage_product  19922 non-null  bool
#  10  description              19920 non-null  object
#  11  product_rating           19922 non-null  object
#  12  overall_rating           19922 non-null  object
#  13  brand                    14071 non-null  object
# ...

# %%
amz_df['product_name'].value_counts()
# Out:
# THELOSTPUPPY BACK COVER FOR APPLE IPAD AIR                       141
# THELOSTPUPPY BACK COVER FOR APPLE IPAD AIR 2                      95
# S4S Stylish Women's Push-up Bra                                   94
# Voylla Metal, Alloy Necklace                                      66
# HomeeHub Polyester Multicolor Self Design Eyelet Door Curtain     58
#                                                                 ...
# VOYLLA ARTIFICTIAL ENAMEL TEXTURED ALLOY JEWEL SET                 1
# MAX WOMEN'S EMPIRE WAIST DRESS                                     1
# NEWGEN TECH EO-HS3303 176 Wired Headset                            1
# Pari & Prince Printed Girl's Jumpsuit                              1
# ARTENGO BSC700 PLASTIC SHUTTLE  - YELLOW                           1
# Name: product_name, Length: 12683, dtype: int64

# %%
flp_df['product_name'].value_counts()
# Out:
# TheLostPuppy Back Cover for Apple iPad Air         134
# TheLostPuppy Back Cover for Apple iPad Air 2        95
# S4S Stylish Women's Push-up Bra                     94
# Voylla Metal, Alloy Necklace                        66
# WallDesign Small Vinyl Sticker                      65
#                                                   ...
# Shyam Fashion Brass Vase                             1
# Denim Deo Combo Set                                  1
# Vero Moda Casual Sleeveless Striped Women's Top      1
# VR Designers Metal, Fabric Necklace                  1
# Sapatos Plain Single Duvet Brown                     1
# Name: product_name, Length: 12626, dtype: int64

# %%
pip install fuzzymatcher
# Out:
# ...
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13909 sha256=73aeeca9bed2aea8d00bb85415a92d874a8380fbc409dc8f39e12b606040972d
#   Stored in directory: c:\users\piyush kumar\appdata\local\pip\cache\wheels\ea\4e\3b\0634f08a7980461ad630fa4147cbd25913b008b4a02992ba66
# Successfully built metaphone
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fuzzymatcher
df=fuzzymatcher.fuzzy_left_join(Flp_df,Amz_df,left_on='product_name',right_on='product_name')

# %%
df.head()
# Out:
#     best_match_score __id_left __id_right                      uniq_id_left  \
# 0           1.104828    0_left    0_right  c2d766ca982eca8304150849735ffef9
# 7           1.101738    1_left    1_right  7f7036a6d550aaa89d34c77bd39a5e48
# 11          0.511402    2_left    2_right  f449ec65dcbc041b6ae5e6a32717d01b
# 12          1.104828    3_left    0_right  0973b37acd0c664e3de26e97e5571454
# 19          1.472761    4_left    4_right  bc940ea42ee6bef5ac7cea3fb5cfbee7
#
#          crawl_timestamp_left  \
# 0   2016-03-25 22:59:23 +0000
# 7   2016-03-25 22:59:23 +0000
# 11  2016-03-25 22:59:23 +0000
# 12  2016-03-25 22:59:23 +0000
# 19  2016-03-25 22:59:23 +0000
#
#                                      product_url_left  \
# 0   http://www.flipkart.com/alisha-solid-women-s-c...
# 7   http://www.flipkart.com/fabhomedecor-fabric-do...
# 11  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 12  http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 143700
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   best_match_score               20000 non-null  float64
#  1   __id_left                      20000 non-null  object
#  2   __id_right                     20000 non-null  object
#  3   uniq_id_left                   20000 non-null  object
#  4   crawl_timestamp_left           20000 non-null  object
#  5   product_url_left               20000 non-null  object
#  6   product_name_left              20000 non-null  object
#  7   product_category_tree_left     20000 non-null  object
#  8   pid_left                       20000 non-null  object
#  9   retail_price_left              19922 non-null  float64
#  10  discounted_price_left          19922 non-null  float64
#  11  image_left                     19997 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['best_match_score', '__id_left', '__id_right', 'uniq_id_left',
#        'crawl_timestamp_left', 'product_url_left', 'product_name_left',
#        'product_category_tree_left', 'pid_left', 'retail_price_left',
#        'discounted_price_left', 'image_left', 'is_FK_Advantage_product_left',
#        'description_left', 'product_rating_left', 'overall_rating_left',
#        'brand_left', 'product_specifications_left', 'uniq_id_right',
#        'crawl_timestamp_right', 'product_url_right', 'product_name_right',
#        'product_category_tree_right', 'pid_right', 'retail_price_right',
#        'discounted_price_right', 'image_right',
#        'is_FK_Advantage_product_right', 'description_right',
#        'product_rating_right', 'overall_rating_right', 'brand_right',
#        'product_specifications_right'],
#       dtype='object')

# %%
# Removing unnecessary columns

df=df.drop(columns=['best_match_score','__id_left','__id_right','uniq_id_left','crawl_timestamp_left','product_url_left','product_category_tree_left', 'pid_left', 'image_left', 'is_FK_Advantage_product_left',
       'description_left', 'product_rating_left', 'overall_rating_left', 'brand_left', 'product_specifications_left', 'uniq_id_right',
       'crawl_timestamp_right', 'product_url_right', 'product_category_tree_right', 'pid_right',
       'image_right', 'is_FK_Advantage_product_right', 'description_right', 'product_rating_right', 'overall_rating_right', 'brand_right',
       'product_specifications_right'])

# %%
df.head(10)
# Out:
#                                     product_name_left  retail_price_left  \
# 0                 Alisha Solid Women's Cycling Shorts              999.0
# 7                 FabHomeDecor Fabric Double Sofa Bed            32157.0
# 11                                         AW Bellies              999.0
# 12                Alisha Solid Women's Cycling Shorts              699.0
# 19              Sicons All Purpose Arnica Dog Shampoo              220.0
# 20  Eternal Gandhi Super Series Crystal Paper Weig...              430.0
# 21                Alisha Solid Women's Cycling Shorts             1199.0
# 28                FabHomeDecor Fabric Double Sofa Bed            32157.0
# 32  dilli bazaaar Bellies, Corporate Casuals, Casuals              699.0
# 33                Alisha Solid Women's Cycling Shorts             1199.0
#
#     discounted_price_left                                 product_name_right  \
# 0                   379.0                Alisha Solid Women's Cycling Shorts
# ...

# %%
df.rename(columns = {'product_name_left':'Product name in Flipkart',
                     'retail_price_left':'Retail price in Flipkart',
                     'discounted_price_left':'Discounted price in Flipkart',
                     'product_name_right':'Product name in Amazon',
                     'retail_price_right':'Retail price in Amazon',
                     'discounted_price_right':'Discounted price in Amzon'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 143700
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Product name in Flipkart      20000 non-null  object
#  1   Retail price in Flipkart      19922 non-null  float64
#  2   Discounted price in Flipkart  19922 non-null  float64
#  3   Product name in Amazon        20000 non-null  object
#  4   Retail price in Amazon        20000 non-null  int64
#  5   Discounted price in Amzon     20000 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
# Result output format

df.head(10)
# Out:
#                              Product name in Flipkart  \
# 0                 Alisha Solid Women's Cycling Shorts
# 7                 FabHomeDecor Fabric Double Sofa Bed
# 11                                         AW Bellies
# 12                Alisha Solid Women's Cycling Shorts
# 19              Sicons All Purpose Arnica Dog Shampoo
# 20  Eternal Gandhi Super Series Crystal Paper Weig...
# 21                Alisha Solid Women's Cycling Shorts
# 28                FabHomeDecor Fabric Double Sofa Bed
# 32  dilli bazaaar Bellies, Corporate Casuals, Casuals
# 33                Alisha Solid Women's Cycling Shorts
#
#     Retail price in Flipkart  Discounted price in Flipkart  \
# 0                      999.0                         379.0
# 7                    32157.0                       22646.0
# 11                     999.0                         499.0
# 12                     699.0                         267.0
# 19                     220.0                         210.0
# ...

# %%
# End
